# %% [markdown]
# ## Homework 1: Part 2
# ## Implementing regularized linear regression
# In this part, you will implement regularized linear regression and use it to
# study models with different bias-variance properties.
#
# This notebook contains code that helps you get started on
# linear regression with regularization.
# You will need to complete functions in
# **reg_linear_regressor.py** and **utils.py**.
# Modify this notebook in places marked by **TODO:**.

# %% [markdown]
# ## Regularized linear regression: an example
# In this problem, you will implement regularized linear regression
# to predict the amount of water flowing out of a dam using the change
# of water level in a reservoir. We will begin by visualizing the dataset containing historical records on the
# change in the water level $x$, and the amount of water $y$, flowing out of the dam.
# This dataset is divided into three parts:
# - A training set that you will use to learn the model:  X,  y.
# - A validation set for determining the regularization parameter: Xval, yval.
# - A test set for evaluating the performance of your model:  Xtest, ytest. These are unseen examples that were not used during the training of the model.
#
# Run the cell below and it  will plot the training data as shown in Figure 6 in your assignment handout.

# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
import plot_utils
from reg_linear_regressor_multi import RegularizedLinearReg_SquaredLoss

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython

# %load_ext autoreload
# %autoreload 2

########################################################################
## =========== Part 1: Loading and Visualizing Data ===================#
########################################################################
# Load Training Data

print 'Loading and Visualizing Data ...'

X, y, Xtest, ytest, Xval, yval = utils.load_mat('ex2data1.mat')

# Plot training data

plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.show()
# Out:
# Loading and Visualizing Data ...

# %% [markdown]
# ## Regularized Linear Regression cost function and gradient (vectorized)
# You should now implement the loss function and gradient of the
# loss function for regularized linear regression in **reg_linear_regression_multi.py**. Then run the cell below.
# Regularized linear regression has the following cost function:
# $$J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right) + \frac{\lambda}{2m}\left( \sum_{j=1}^{n} {\theta_j}^2 \right) $$
# where $\lambda$ is a regularization parameter which controls the degree of regularization
# (thus, help preventing overfitting). The regularization term puts
# a penalty on the overall cost $J(\theta)$. As the magnitudes of the model parameters $\theta_j$ increase, the penalty increases as well. Note that you should not regularize the $\theta_0$ term. You should now complete the code for the method loss in the class Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py to calculate $J(\theta)$. Vectorize your code and avoid writing for loops.
#
# Correspondingly, the partial derivative of the regularized linear regression  cost function
# with respect to  $\theta_j$ is defined as:
# \begin{eqnarray*}
# \frac{\partial J(\theta)}{\partial \theta_0} & = & \frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)}){x_j}^{(i)} \\
# \frac{\partial J(\theta)}{\partial \theta_j} & = & \left(\frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)} ){x_j}^{(i)}\right) + \frac{\lambda}{m}{\theta_j} \; \; \; \mbox{ for }j \geq 1\\
# \end{eqnarray*}
# You should now complete the code for the method grad_loss in the class {Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py}
# to  calculate the gradient, returning
# it in the variable grad.
#
# Then evaluate the cell below. It runs the train method in  reg_linear_regressor_multi.py to compute the optimal value
# of $\theta$. This training function uses scipy's fmin_bfgs to optimize the cost function.
# Here we have set the regularization parameter $\lambda$ to zero.
#
# The best fit line plotted by the script  tells us that the model is
# not a good fit to the data because the data is non-linear. While
# visualizing the best fit as shown is one possible way to debug your learning
# algorithm, it is not always easy to visualize the data and model. In the next
# cell, you will implement a function to generate learning curves that can
# help you debug your learning algorithm even if it is not easy to visualize the
# data.

# %%
# append a column of ones to matrix X

XX = np.vstack([np.ones((X.shape[0],)),X]).T

#  Train linear regression with lambda = 0

reglinear_reg1 = RegularizedLinearReg_SquaredLoss()
theta_opt0 = reglinear_reg1.train(XX,y,reg=0.0,num_iters=1000)
print 'Theta at lambda = 0 is ', theta_opt0

# plot fit over data and show it (or save it in fig7.pdf)
plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.plot(X,np.dot(XX,theta_opt0),'g-',linewidth=3)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 22.373906
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Theta at lambda = 0 is  [ 13.08790353   0.36777923]

# %% [markdown]
# ## Learning curve for linear regression
# An important concept in machine learning is the bias-variance tradeoff. Models
# with high bias are not complex enough for the data and tend to underfit,
# while models with high variance overfit  the training data.
# Here you will plot training and test errors on a
# learning curve to diagnose bias-variance problems.
#
# A  learning curve plots
# training and cross validation error as a function of training set size. You will complete the
# function  learning_curve in utils.py so that it returns a vector of errors for the
# training set and  validation set.
# To obtain different training set sizes,
# use different subsets of the original training set X. Specifically, for
# a training set size of $i$, you should use the first $i$ examples.
#
# You can use the train function to find the parameter $\theta$. Note
# that the regularization $\lambda$  is passed as a parameter to the learning_curve function.
# After learning the $\theta$ parameter, you should compute the error on the training
# and validation sets. Recall that the training error for a dataset is
# defined as:
# $$ J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right)  $$
#
#
# In particular, note that the training error does not include the regularization
# term. One way to compute the training error is to use your existing
# cost function and set the regularization parameter reg to 0 only when using it to compute the training error
# and validation error. When you are computing the training set error,
# make sure you compute it on the training subset
# instead of the entire training set. However, for the validation error,
# you should compute it over the entire validation set. You should store
# the computed errors in the vectors error_train and error_val.
# When you are finished, the cell below will print the learning curves and produce
# a plot similar to Figure 8 in the assignment handout.

# %%
reg = 1.0
XXval = np.vstack([np.ones((Xval.shape[0],)),Xval]).T

# implement the learning_curve function in utils.py
# this script will run your function and show the learning curve

error_train, error_val = utils.learning_curve(XX,y,XXval,yval,reg)
plot_utils.plot_learning_curve(error_train, error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.001307
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 3.335017
#          Iterations: 3
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 2.881847
#          Iterations: 3
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 13.174273
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 19.461396
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 20.112149
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 18.184047
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 22.618880
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 23.268598
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 24.323253
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 22.379542
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6

# %% [markdown]
# ## Polynomial regression: expanding the basis functions
# The problem with our linear model was that it was too simple for the data
# and resulted in underfitting (high bias). In this problem, you will address this issue by adding more features. In particular, you will consider hypotheses of the form
# $$ h_\theta(x) = \theta_0 + \theta_1 x + \theta_2 x^2 + \ldots + \theta_p x^p $$
# This is still a linear model from the point of view of the parameter space. We have augmented the features with powers of $x$.
# Code in the cell below builds these features using sklearn's preprocessing module.
#
# We use a polynomial of degree 6.
# It turns out that if we run the training directly on the projected data,  it will
# not work well as the features would be badly scaled (e.g., an example with
# $x = 40$ will now have a feature $x^6 = 40^6 = 4.1 \times 10^{9}$). Therefore, you will
# need to use feature normalization.
# Before learning the parameter $\theta$ for the polynomial regression, the script in the cell below will
# first call the **feature_normalize** function you wrote earlier. It will normalize the features of the training set,
# storing the mu, sigma parameters separately. It will project the validation and test sets too, but normalize them using the same mu and sigma parameters.

# %%
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Map X onto polynomial features and normalize
# We will consider a 6th order polynomial fit for the data

p = 6
poly = sklearn.preprocessing.PolynomialFeatures(degree=p,include_bias=False)
X_poly = poly.fit_transform(np.reshape(X,(len(X),1)))
X_poly, mu, sigma = utils.feature_normalize(X_poly)

# add a column of ones to X_poly

XX_poly = np.vstack([np.ones((X_poly.shape[0],)),X_poly.T]).T

# map Xtest and Xval into the same polynomial features

X_poly_test = poly.fit_transform(np.reshape(Xtest,(len(Xtest),1)))
X_poly_val = poly.fit_transform(np.reshape(Xval,(len(Xval),1)))

# normalize these two sets with the same mu and sigma

X_poly_test = (X_poly_test - mu) / sigma
X_poly_val = (X_poly_val - mu) / sigma

# add a column of ones to both X_poly_test and X_poly_val
XX_poly_test = np.vstack([np.ones((X_poly_test.shape[0],)),X_poly_test.T]).T
XX_poly_val = np.vstack([np.ones((X_poly_val.shape[0],)),X_poly_val.T]).T

# %% [markdown]
# ## Learning curves for polynomial regression
# The cell below trains a linear model on the transformed data. After learning $\theta$, you should see two plots
# generated for polynomial regression with $\lambda= 0$.

# %%
reg = 0.0
reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
theta_opt1 = reglinear_reg1.train(XX_poly,y,reg=reg,num_iters=10000)
print 'Theta at lambda = 0 is ', theta_opt1


# plot data and training fit for the 6th order polynomial 

plot_utils.plot_fit(X,y,np.min(X),np.max(X),mu,sigma,theta_opt1,p,'Change in water level (x)','Water flowing out of dam (y)','Polynomial Regression fit with lambda = 0 and polynomial features of degree = ' + str(p))
plt.show()

# plot learning curve for data (6th order polynomail basis function) 

error_train,error_val = utils.learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Theta at lambda = 0 is  [ 11.21758977  10.88676468  12.86207254  10.28506173  -4.20098901
#  -11.4141408   -4.90366713]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2
#          Function evaluations: 3
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 34
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 48
#          Function evaluations: 50
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: 0.075859
#          Iterations: 48
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 0.183744
#          Iterations: 45
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.224868
#          Iterations: 46
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.204675
#          Iterations: 46
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45

# %% [markdown]
# ## Adjusting the regularization parameter
# You will now explore how the regularization parameter
# affects the bias-variance of regularized polynomial regression. You should
# now modify the  lambda parameter in the cell above and try $\lambda = 1, 10, 100$. For
# each of these values, the script will generate a polynomial fit to the data
# and also a learning curve. Submit two plots for each value of lambda: the fit as well as the learning curve. Comment on the impact of the choice of lambda on the quality of the learned model in your **writeup.pdf**.

# %%
regs = [1.0, 10.0, 100.0]
for reg in regs:
    reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
    theta_opt1 = reglinear_reg1.train(XX_poly, y, reg = reg, num_iters = 10000)
    print 'Theta at lambda =', reg, ' is ', theta_opt1

# plot data and training fit for the 6th order polynomial 
    reg_p = str(reg) + ' , ' + str(p)
    plot_utils.plot_fit(X, y, np.min(X), np.max(X), mu, sigma, theta_opt1, p, 'Change in water level (x)', 'Water flowing out of dam (y)', 'Polynomial Regression fit with lambda and polynomial features of degree are ' + reg_p)
    plt.show()

# plot learning curve for data (6th order polynomail basis function) 

    error_train,error_val = utils.learning_curve(XX_poly,y,XX_poly_val,yval,reg)
    plot_utils.plot_learning_curve(error_train,error_val,reg)
    plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 6.891076
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Theta at lambda = 1.0  is  [ 11.21758965   8.38063919   5.2189995    3.62613002   2.11031236
#    1.95477335   0.7852622 ]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.070596
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 17.745495
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 14.040584
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 11.237114
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 9.777938
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 9.000510
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 7.901350
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 7.487337
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 6.784528
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 6.170515
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 6.891076
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 32.613222
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Theta at lambda = 10.0  is  [ 11.21758914   4.46192704   2.41291632   3.02877425   1.45338351
#    2.00441329   0.81193983]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.108555
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 75.660685
#          Iterations: 9
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 74.830449
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 60.966522
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 55.961503
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 48.157528
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 42.920531
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 39.912090
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 35.927539
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 32.841691
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 32.613222
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 66.787978
#          Iterations: 13
#          Function evaluations: 18
#          Gradient evaluations: 18
# Theta at lambda = 100.0  is  [  1.12175893e+01   1.01732906e+00   3.17218425e-01   7.98987676e-01
#    1.26291076e-01   6.03254859e-01  -5.02063756e-03]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 5
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.114724
#          Iterations: 6
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 112.490153
#          Iterations: 9
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 132.168613
#          Iterations: 11
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 118.185547
#          Iterations: 15
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 110.243586
#          Iterations: 12
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 94.565694
#          Iterations: 10
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 87.386837
#          Iterations: 13
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 81.076831
#          Iterations: 13
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 74.006728
#          Iterations: 13
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 67.720440
#          Iterations: 12
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 66.787978
#          Iterations: 13
#          Function evaluations: 18
#          Gradient evaluations: 18

# %% [markdown]
# ## Calculating test error on the best model
# To get a better indication of a model's performance in the real
# world, it is important to evaluate the final model on a test set that was
# not used in any part of training (that is, it was neither used to select the regularization parameter, nor to learn the model parameters).
# Calculate the error of the best model that you found with the previous analysis
# and report it.

# %%
# TODO: your code for computing test error on the best model (model with the best lambda)
reg = 1.0

linear_reg = RegularizedLinearReg_SquaredLoss()
    
theta_opt = linear_reg.train(XX_poly, y, reg = reg, num_iters = 1000)
    
error_test = linear_reg.loss(theta_opt, XX_poly_test, ytest, 0)

print 'Test error on lambda = 1 is ', error_test
# Out:
# Optimization terminated successfully.
#          Current function value: 6.891076
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Test error on lambda = 1 is  3.09874826556

# %% [markdown]
# ## Selecting $\lambda$ using a validation set
# You will implement an automated method to select the $\lambda$ parameter. Concretely, you will use a validation set to evaluate how good each $\lambda$ value is. After selecting the best $\lambda$ value using the
# validation set, we can then evaluate the model on the test set to estimate
# how well the model will perform on actual unseen data.
# **Complete the function validation_curve.m in utils.py**. Specifically,
# you should should use the train method on an instance of the class Reg_Linear_Regressor to train the model using
# different values of $\lambda$ and to compute the training error and  validation error.
# You should try $\lambda$ in the following range: \{0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10\}.
#
# After you have completed the code, run the cell below to plot a validation curve of $\lambda$ versus the error. This plot  allows you select
# which $\lambda$ value to use. Due to randomness
# in the training and validation splits of the dataset, the cross validation error
# can sometimes be lower than the training error. Submit a pdf version of this plot in **writeup.pdf**. Comment on the best choice of $\lambda$ for this problem.

# %%
# now implement the validation_curve function in utils.py
# this function helps in determining the best lambda using a
# a validation set
# The code will now run your function and plot the figure 

reg_vec, error_train, error_val = utils.validation_curve(XX_poly,y,XX_poly_val,yval)
plot_utils.plot_lambda_selection(reg_vec,error_train,error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.220253
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.260109
#          Iterations: 42
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.378278
#          Iterations: 41
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.647252
#          Iterations: 37
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 1.372851
#          Iterations: 34
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 2.931334
#          Iterations: 28
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 6.891076
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 32.613222
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10

# %% [markdown]
# ## Plotting learning curves with randomly selected examples
# In practice, especially for small training sets, when you plot learning curves
# to debug your algorithms, it is often helpful to average across multiple sets
# of randomly selected examples to determine the training error and
# validation error.
# Concretely, to determine the training error and cross validation error for
# $i$ examples, you should first randomly select $i$ examples from the training set
# and $i$ examples from the  validation set. You will then learn the model parameters using the randomly chosen training set and evaluate the parameters on the randomly chosen training set and validation set. The above
# steps should then be repeated multiple times (say 50) and the averaged error
# should be used to determine the training error and cross validation error for
# $i$ examples.
# Implement the above
# strategy for computing the learning curves. Complete the  function
# **learning_curve_averaged** in  **utils.py** to generate compute and generate this plot. Then evaluate the cell below.

# %%
# Now implement the averaged learning curve function in utils.py
# The script runs your function, plots the curves and saves it in fig11.pdf

reg = 3.0
error_train, error_val = utils.averaged_learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 46.995814
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 22.901630
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 56.812547
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.012109
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 41.658673
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.298207
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.551720
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.006842
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1.496901
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.063925
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 5.571818
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.240619
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 52.295311
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.347872
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.077646
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 41.946108
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 54.279539
#          Iterations: 10
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 41.658673
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.012109
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 22.901630
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.016407
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.551720
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 56.830898
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 53.587122
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 3.365835
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 16.326044
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 16.441022
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 52.295311
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.298207
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 43.261986
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 33.976907
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.095274
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 1.875809
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.095274
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.017440
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.063305
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 8.321699
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 33.976907
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.756160
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 14.073634
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 53.587122
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 14.179284
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 56.830898
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 55.180095
#          Iterations: 10
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.017440
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.063305
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000963
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000963
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 40.762838
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 31.808295
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 22.183648
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 32.213303
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 9.855323
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 39.198127
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 2.530207
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 11.839126
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.118462
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 43.533917
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 32.621677
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 3.117847
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 26.415366
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 2.403419
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 31.808295
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 41.294447
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1.894762
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.456128
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 38.004277
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 27.214222
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 38.898258
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.275899
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 38.638947
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 33.944842
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 2.403419
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 25.586440
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.275899
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 3.117847
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 41.993462
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 31.708496
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 41.554156
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 19.370576
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 14.519947
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 2.414107
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.152950
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 39.497823
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 40.403741
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 26.231131
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.234985
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 2.447833
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 37.876843
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 37.877532
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 23.273085
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 32.590829
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 9.855323
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 31.708496
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.010993
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 2.403419
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 15.942209
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 31.708496
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 28.480651
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 23.564251
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 30.576651
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 10.117423
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 22.131513
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 8.939694
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 30.529137
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 33.606800
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 10.525215
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 5.674330
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 29.716864
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 31.526997
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 36.130683
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1.828957
#          Iterations: 9
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 33.510677
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 25.458667
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 9.758327
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 37.680697
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 22.748241
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 36.161866
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 31.952446
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 36.832925
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 36.510146
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.244222
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 12.542988
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 30.776126
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 30.439708
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 8.711470
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 29.716864
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 23.010774
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 29.248592
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 25.127722
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 8.711470
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 29.188783
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 32.427331
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 31.841441
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 32.725498
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 32.311469
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 9.524107
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 17.411020
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 2.281435
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 24.011475
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1.779048
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 8.855274
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 31.620333
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 37.652492
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 33.606800
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 23.925043
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 25.018331
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 8.518461
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 25.196588
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 23.561563
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 25.403807
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 27.490255
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 26.451741
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1.873798
#          Iterations: 10
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 26.210092
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 20.126404
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1.839494
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 26.466009
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 31.059141
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 17.747171
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 21.331817
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 20.787767
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 27.059306
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 24.037845
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 26.210092
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 26.079788
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 23.651904
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 21.799498
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 21.625344
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 24.694665
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1.838997
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 29.330303
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 22.713781
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 10.268632
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 25.623879
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 26.271966
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 28.092213
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 20.314409
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 2.062676
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 9.224701
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 20.252762
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 7.156379
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 24.630173
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 24.871748
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 26.172080
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 8.734491
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 19.367735
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 19.740874
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 29.756695
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 24.511923
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 21.109646
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 31.181262
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.156255
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 32.954271
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 25.794895
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 23.858629
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 26.051610
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 21.311250
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 18.552401
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 25.246097
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 15.052750
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 23.094163
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 18.652163
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 24.204815
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 24.371607
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 23.335169
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 22.518176
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 23.845565
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 25.582061
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 7.292969
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 24.822500
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 18.930508
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 26.895799
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 22.912128
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 25.145507
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 24.216171
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 16.126590
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 21.306927
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 24.862185
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 23.578245
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 24.929755
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 16.513672
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1.667701
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 25.075299
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 24.216171
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 24.653807
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 21.999855
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 17.972516
#          Iterations: 11
# ...
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.600779
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.925755
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 16.594923
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 16.366350
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.586481
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 16.469141
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.469141
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.750218
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 16.600779
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 16.594923
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 16.282133
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 14.724148
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.750218
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.880483
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 16.586481
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.282133
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.247044
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.750218
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.750218
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.750218
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.594923
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 15.880483
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 16.594923
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 16.282133
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.469141
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.880483
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 16.586481
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 16.366350
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 14.724148
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 16.366350
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.366350
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 16.600779
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 14.724148
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 15.925755
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 15.925755
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 16.469141
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.547140
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 15.237513
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16

# %% [markdown]
# ## Extra Credit: Building regularized models for Boston data set
# Perform a bias variance analysis of the Boston housing data set with the thirteen predictors, following the steps on the simple data set above. Use sklearn's  built-in functions to split the data into training, validation and test sets. What is the lowest achievable error on the test set with $\lambda = 0$? Select the best value for $\lambda$ and report the test set error with the best $\lambda$. Use the technique of adding features to extend each column of the Boston data set with powers of the values in the column. Repeat the bias-variance analysis with quadratic and cubic features. What is the test set error with quadratic features with the best $\lambda$ chosen with the validation set? What is the test set error with cubic features with the best $\lambda$ chosen with the validation set? Put your analysis code in a separate Python script or notebook called bostonexpt.py or bostonexpt.ipynb. Present your results analytically with plots to support your findings. Discuss the impact of regularization for building good models for the Boston housing data set.

# %%
# Import the function and data sets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils
import plot_utils
from sklearn.datasets import load_boston
from reg_linear_regressor_multi import RegularizedLinearReg_SquaredLoss
from sklearn.model_selection import train_test_split

# %load_ext autoreload
# %autoreload 2

## Loading & spliting the data
print 'Reading data ...'
boston_data = load_boston()
df = pd.DataFrame(data = boston_data.data, columns = boston_data.feature_names)
df
X = df.values
y = boston_data.target
X, Xtest, y, ytest = train_test_split(X, y, test_size = 0.2, random_state = 1)
X, Xval, y, yval = train_test_split(X, y, test_size = 0.2, random_state = 1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Reading data ...

# %%
XX = np.vstack([np.ones((X.shape[0], )), X.T]).T
reglinear_reg_a = RegularizedLinearReg_SquaredLoss()
op_theta_a = reglinear_reg_a.train(XX, y, reg = 0.0, num_iters = 3000)
print 'When λ = 0, the optimal theta is ', op_theta_a
# Out:
# Optimization terminated successfully.
#          Current function value: 11.164041
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# When λ = 0, the optimal theta is  [  5.16919287e+01  -1.19855045e-01   6.71776448e-02   5.59423407e-02
#    2.36539069e+00  -2.34426891e+01   2.21750928e+00   1.60852842e-02
#   -1.54171817e+00   3.14727410e-01  -1.00394479e-02  -1.06202769e+00
#    6.13801356e-03  -6.14267526e-01]

# %%
# The lowest achievable error on the test set with λ = 0
XXtest = np.vstack([np.ones((Xtest.shape[0], )), Xtest.T]).T
error_test = reglinear_reg_a.loss(op_theta_a, XXtest, ytest, 0)
print 'lowest achievable error on the test set with λ = 0 is ', error_test
# Out:
# lowest achievable error on the test set with λ = 0 is  12.9277921155

# %%
XXval = np.vstack([np.ones((Xval.shape[0], )), Xval.T]).T

# Implement the validation_curve function in utils.py
# This function helps in determining the best lambda using
# a validation set
reg_vec, error_train, error_val = utils.validation_curve(XX, y, XXval, yval)
plot_utils.plot_lambda_selection(reg_vec, error_train, error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 11.164041
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.164914
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.166653
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.172687
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.189474
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.243434
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.365817
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 11.604927
#          Iterations: 43
#          Function evaluations: 50
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: 11.847110
#          Iterations: 40
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 12.083887
#          Iterations: 38
#          Function evaluations: 45
#          Gradient evaluations: 45

# %%
# The test error with λ=0.1
reg = 0.3
XXtest = np.vstack([np.ones((Xtest.shape[0], )), Xtest.T]).T
linear_reg_b = RegularizedLinearReg_SquaredLoss()
error_test = linear_reg_b.loss(op_theta_a, XXtest, ytest, reg)
print 'The lowest achievable Test Error at λ = 0.3 is ', error_test
# Out:
# The lowest achievable Test Error at λ = 0.3 is  13.7573151655

# %%
# Polynomial regression
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Consider 2nd order polynomial fit
p = 2
poly = sklearn.preprocessing.PolynomialFeatures(degree = p, include_bias = False)
X_poly = poly.fit_transform(X)
X_poly, mu, sigma = utils.feature_normalize(X_poly)
XX_poly = np.vstack([np.ones((X_poly.shape[0], )), X_poly.T]).T

# map Xtest and Xval into the same polynomial features
X_poly_test = poly.fit_transform(Xtest)
X_poly_val = poly.fit_transform(Xval)

# normalize
X_poly_test = (X_poly_test - mu) / sigma
X_poly_val = (X_poly_val - mu) / sigma
XX_poly_test = np.vstack([np.ones((X_poly_test.shape[0], )), X_poly_test.T]).T
XX_poly_val = np.vstack([np.ones((X_poly_val.shape[0], )), X_poly_val.T]).T

# %%
# Implement the validation_curve function in utils.py
# This function helps in determining the best lambda using
# a validation set
reg_vec, error_train, error_val = utils.validation_curve(XX_poly, y, XX_poly_val, yval)
plot_utils.plot_lambda_selection(reg_vec, error_train, error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 2.859683
#          Iterations: 873
#          Function evaluations: 877
#          Gradient evaluations: 877
# Optimization terminated successfully.
#          Current function value: 2.885003
#          Iterations: 763
#          Function evaluations: 767
#          Gradient evaluations: 767
# Optimization terminated successfully.
#          Current function value: 2.919023
#          Iterations: 654
#          Function evaluations: 658
#          Gradient evaluations: 658
# Optimization terminated successfully.
#          Current function value: 3.004209
#          Iterations: 500
#          Function evaluations: 504
#          Gradient evaluations: 504
# Optimization terminated successfully.
#          Current function value: 3.167705
#          Iterations: 392
#          Function evaluations: 396
#          Gradient evaluations: 396
# Optimization terminated successfully.
#          Current function value: 3.498354
#          Iterations: 278
#          Function evaluations: 282
#          Gradient evaluations: 282
# Optimization terminated successfully.
#          Current function value: 3.967979
#          Iterations: 194
#          Function evaluations: 198
#          Gradient evaluations: 198
# Optimization terminated successfully.
#          Current function value: 4.685218
#          Iterations: 129
#          Function evaluations: 133
#          Gradient evaluations: 133
# Optimization terminated successfully.
#          Current function value: 5.586284
#          Iterations: 85
#          Function evaluations: 89
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: 6.990856
#          Iterations: 52
#          Function evaluations: 56
#          Gradient evaluations: 56

# %%
## the test error with "best" λ=0.3
reg = 0.3
linear_reg_c = RegularizedLinearReg_SquaredLoss()
op_theta_b = linear_reg_c.train(XX_poly, y, reg = reg, num_iters = 3000)
error_test = linear_reg_c.loss(op_theta_b, XX_poly_test, ytest, reg)
print 'the test error with best λ = 0.3 is ', error_test
# Out:
# Optimization terminated successfully.
#          Current function value: 3.967979
#          Iterations: 194
#          Function evaluations: 198
#          Gradient evaluations: 198
# the test error with best λ = 0.3 is  5.54242712413

# %%
# Polynomial regression
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Consider 3nd order polynomial fit
p = 3
poly = sklearn.preprocessing.PolynomialFeatures(degree = p, include_bias = False)
X_poly_a = poly.fit_transform(X)
X_poly_a, mu_a, sigma_a = utils.feature_normalize(X_poly_a)
XX_poly_a = np.vstack([np.ones((X_poly_a.shape[0], )), X_poly_a.T]).T

# map Xtest and Xval into the same polynomial features
X_poly_test_a = poly.fit_transform(Xtest)
X_poly_val_a = poly.fit_transform(Xval)

# normalize
X_poly_test_a = (X_poly_test_a - mu_a) / sigma_a
X_poly_val_a = (X_poly_val_a - mu_a) / sigma_a
XX_poly_test_a = np.vstack([np.ones((X_poly_test_a.shape[0], )), X_poly_test_a.T]).T
XX_poly_val_a = np.vstack([np.ones((X_poly_val_a.shape[0], )), X_poly_val_a.T]).T

# %%
# Implement the validation_curve function in utils.py
# This function helps in determining the best lambda using
# a validation set
reg_vec, error_train, error_val = utils.validation_curve(XX_poly_a, y, XX_poly_val_a, yval)
plot_utils.plot_lambda_selection(reg_vec, error_train, error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.030314
#          Iterations: 2383
#          Function evaluations: 2392
#          Gradient evaluations: 2392
# Optimization terminated successfully.
#          Current function value: 0.387298
#          Iterations: 1163
#          Function evaluations: 1171
#          Gradient evaluations: 1171
# Optimization terminated successfully.
#          Current function value: 0.554243
#          Iterations: 962
#          Function evaluations: 970
#          Gradient evaluations: 970
# Optimization terminated successfully.
#          Current function value: 0.807469
#          Iterations: 702
#          Function evaluations: 710
#          Gradient evaluations: 710
# Optimization terminated successfully.
#          Current function value: 1.101031
#          Iterations: 512
#          Function evaluations: 520
#          Gradient evaluations: 520
# Optimization terminated successfully.
#          Current function value: 1.486513
#          Iterations: 348
#          Function evaluations: 356
#          Gradient evaluations: 356
# Optimization terminated successfully.
#          Current function value: 1.925964
#          Iterations: 236
#          Function evaluations: 244
#          Gradient evaluations: 244
# Optimization terminated successfully.
#          Current function value: 2.575335
#          Iterations: 150
#          Function evaluations: 158
#          Gradient evaluations: 158
# Optimization terminated successfully.
#          Current function value: 3.354008
#          Iterations: 96
#          Function evaluations: 105
#          Gradient evaluations: 105
# Optimization terminated successfully.
#          Current function value: 4.413390
#          Iterations: 63
#          Function evaluations: 72
#          Gradient evaluations: 72

# %%
## the test error with "best" λ=10
reg = 10
linear_reg_d = RegularizedLinearReg_SquaredLoss()
op_theta_c = linear_reg_d.train(XX_poly_a, y, reg = reg, num_iters = 3000)
error_test = linear_reg_d.loss(op_theta_c, XX_poly_test_a, ytest, reg)
print 'the test error with best λ = 10 is ', error_test
print 'overfitting in this case!'
print 'λ = 0.3 will perform much better'
# Out:
# Optimization terminated successfully.
#          Current function value: 4.413390
#          Iterations: 63
#          Function evaluations: 72
#          Gradient evaluations: 72
# the test error with best λ = 10 is  7.11306919569
# overfitting in this case!
# λ = 0.3 will perform much better
